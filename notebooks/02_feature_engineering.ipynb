# %%
import pandas as pd
import numpy as np

# %%
fact_sales = pd.read_parquet("../data/FACT_SALES.parquet")

fact_sales.head()
# Out:
#   OrderLineID Invoice  DateID  ProductID CustomerID  GeographyID WarehouseID  \
# 0      186959  507177   123.0       3470      GUEST           21    WH-UK-02
# 1       42348  492951    19.0       3470    16525.0           21    WH-UK-01
# 2      874576  567477   535.0       3470    16327.0           21    WH-UK-01
# 3      547630  538153   307.0       3470      GUEST           21    WH-UK-01
# 4      143522  503047    94.0       3470      GUEST           21    WH-UK-01
#
#    OrderContextID  Quantity UnitPriceGBP UnitCostGBP DeliveryTime  SalesAmount
# 0             146       2.0        20.99       11.46            5        41.98
# 1             162      36.0        20.99       11.46           10       755.64
# 2             170       6.0        20.99       11.46            8       125.94
# 3              63       2.0        20.99       11.46           13        41.98
# 4              63       1.0        20.99       11.46            9        20.99

# %%
fact_sales.shape
# Out:
# (1072336, 13)

# %%
fact_sales.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1072336 entries, 0 to 1072335
# Data columns (total 13 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   OrderLineID     1072336 non-null  str
#  1   Invoice         1072336 non-null  str
#  2   DateID          1061793 non-null  float64
#  3   ProductID       1072336 non-null  int64
#  4   CustomerID      1072336 non-null  str
#  5   GeographyID     1072336 non-null  int64
#  6   WarehouseID     1072336 non-null  str
#  7   OrderContextID  1072336 non-null  int64
#  8   Quantity        1072335 non-null  float64
#  9   UnitPriceGBP    1072336 non-null  str
#  10  UnitCostGBP     1071292 non-null  str
#  11  DeliveryTime    1071521 non-null  str
#  12  SalesAmount     1063595 non-null  float64
# dtypes: float64(3), int64(3), str(7)
# memory usage: 143.8 MB

# %%
dim_product = pd.read_parquet("../data/DIM_PRODUCT.parquet")

dim_customer = pd.read_parquet("../data/DIM_CUSTOMER.parquet")

dim_date = pd.read_parquet("../data/DIM_DATE.parquet")

dim_warehouse = pd.read_parquet("../data/DIM_WAREHOUSE.parquet")

dim_geography = pd.read_parquet("../data/DIM_GEOGRAPHY.parquet")

dim_order_context = pd.read_parquet("../data/DIM_ORDER_CONTEXT.parquet")

# %%
fact_sales.columns
# Out:
# Index(['OrderLineID', 'Invoice', 'DateID', 'ProductID', 'CustomerID',
#        'GeographyID', 'WarehouseID', 'OrderContextID', 'Quantity',
#        'UnitPriceGBP', 'UnitCostGBP', 'DeliveryTime', 'SalesAmount'],
#       dtype='str')

# %%
dim_product.columns
# Out:
# Index(['ProductID', 'StockCode', 'ProductNameClean', 'ProductCategoryCode',
#        'ProductCategory', 'ProductFamily'],
#       dtype='str')

# %%
dim_warehouse.columns
# Out:
# Index(['WarehouseID'], dtype='str')

# %%
dim_date.columns
# Out:
# Index(['DateID', 'Date', 'Year', 'Quarter', 'Month', 'MonthName', 'WeekOfYear',
#        'Day', 'DayName', 'DayOfWeek', 'IsWeekend'],
#       dtype='str')
